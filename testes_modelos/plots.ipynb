# %%
pct_bm25 = 46.43
ndcg_bm25 = 0.5298

pct_bm25_semantic = 40.45
ndcg_bm25_semantic = 0.6020

pct_colbert_local = 54.43
ndcg_colbert_local = 0.6595

pct_colbert_global = 53.95
ndcg_colbert_global = 0.6904

pct_bm25_semantic_colbert_local = 52.55
ndcg_bm25_semantic_colbert_local = 0.6855

pct_bm25_semantic_colbert_global = 47.99
ndcg_bm25_semantic_colbert_global = 0.6560

# %%
import matplotlib.pyplot as plt

# Dados das métricas
metodos = [
    'BM25', 
    'BM25 + Semantic', 
    'ColBERT Local', 
    'ColBERT Global', 
    'BM25/Semantic + ColBERT Local', 
    'BM25/Semantic + ColBERT Global'
]

pct = [
    46.43, 
    40.45, 
    54.43, 
    53.95, 
    52.55, 
    47.99
]

ndcg = [
    0.5298, 
    0.6020, 
    0.6595, 
    0.6904, 
    0.6855, 
    0.6560
]

# Plot de Percentagens
plt.figure(figsize=(10, 5))
plt.bar(metodos, pct, color=['blue', 'orange', 'green', 'red', 'purple', 'brown'])
plt.xlabel('Métodos')
plt.ylabel('Percentagem (%)')
plt.title('Percentagens por Método')
plt.xticks(rotation=45, ha='right')
plt.legend(['Percentagens'], loc='upper left')
plt.tight_layout()

# Plot de NDCG
plt.figure(figsize=(10, 5))
plt.bar(metodos, ndcg, color=['blue', 'orange', 'green', 'red', 'purple', 'brown'])
plt.xlabel('Métodos')
plt.ylabel('NDCG')
plt.title('NDCG por Método')
plt.xticks(rotation=45, ha='right')
plt.legend(['NDCG'], loc='upper left')
plt.tight_layout()

plt.show()
